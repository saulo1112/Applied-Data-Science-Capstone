# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab: Interactive Visual Analytics with Folium**

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# The launch success rate may depend on many factors such as payload mass, orbit type, and so on. It may also depend on the location and proximities of a launch site, i.e., the initial position of rocket trajectories. Finding an optimal location for building a launch site certainly involves many factors and hopefully we could discover some of the factors by analyzing the existing launch site locations.

# %% [markdown]
# In the previous exploratory data analysis labs, you have visualized the SpaceX launch dataset using `matplotlib` and `seaborn` and discovered some preliminary correlations between the launch site and success rates. In this lab, you will be performing more interactive visual analytics using `Folium`.

# %% [markdown]
# ## Objectives

# %% [markdown]
# This lab contains the following tasks:
#
# *   **TASK 1:** Mark all launch sites on a map
# *   **TASK 2:** Mark the success/failed launches for each site on the map
# *   **TASK 3:** Calculate the distances between a launch site to its proximities
#
# After completed the above tasks, you should be able to find some geographical patterns about launch sites.

# %% [markdown]
# Let's first import required Python packages for this lab:

# %%
import piplite
await piplite.install(['folium'])
await piplite.install(['pandas'])

# %%
import folium
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# If you need to refresh your memory about folium, you may download and refer to this previous folium lab:

# %% [markdown]
# [Generating Maps with Python](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/v4/DV0101EN-Exercise-Generating-Maps-in-Python.ipynb)

# %% [markdown]
# First, let's try to add each site's location on a map using site's latitude and longitude coordinates

# %% [markdown]
# The following dataset with the name `spacex_launch_geo.csv` is an augmented dataset with latitude and longitude added for each site.

# %%
# Download and read the `spacex_launch_geo.csv`
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df=pd.read_csv(spacex_csv_file)

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# Now, you can take a look at what are the coordinates for each site.

# %% [markdown]
# Above coordinates are just plain numbers that can not give you any intuitive insights about where are those launch sites. If you are very good at geography, you can interpret those numbers directly in your mind. If not, that's fine too. Let's visualize those locations by pinning them on a map.

# %% [markdown]
# We first need to create a folium `Map` object, with an initial center location to be NASA Johnson Space Center at Houston, Texas.

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %%
## Task 1: Mark all launch sites on a map
# instantiate a feature group for the incidents in the dataframe
Launch_Sites = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for Lt, Lng, in zip(launch_sites_df.Lat, launch_sites_df.Long):
    Launch_Sites.add_child(
        folium.vector_layers.CircleMarker(
            [Lt, Lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )
# add pop-up text to each marker on the map
latitudes = list(launch_sites_df.Lat)
longitudes = list(launch_sites_df.Long)
labels = list(launch_sites_df['Launch Site'])

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(site_map)    

# add incidents to map
site_map.add_child(Launch_Sites)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d2b9a478fb70972d08824976e5804af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d2b9a478fb70972d08824976e5804af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d2b9a478fb70972d08824976e5804af = L.map(
#                 &quot;map_5d2b9a478fb70972d08824976e5804af&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0317f6701c46ca0dc250269099a72f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0317f6701c46ca0dc250269099a72f3.addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#             var marker_a03b15a6eeb92c066b9803b5333350b9 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_fd0a4d89b7cbbaf71f465620fc75a699 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14adabd1275dbc613706b9df78ca4feb = $(`&lt;div id=&quot;html_14adabd1275dbc613706b9df78ca4feb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_fd0a4d89b7cbbaf71f465620fc75a699.setContent(html_14adabd1275dbc613706b9df78ca4feb);
#
#
#
#         marker_a03b15a6eeb92c066b9803b5333350b9.bindPopup(popup_fd0a4d89b7cbbaf71f465620fc75a699)
#         ;
#
#
#
#
#             var marker_5f054e3195393eb5865b956f50757656 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_a53d2d6012714fcab0eb6d7fe906509f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc0a77eab94ff78051569f6146506cdf = $(`&lt;div id=&quot;html_fc0a77eab94ff78051569f6146506cdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_a53d2d6012714fcab0eb6d7fe906509f.setContent(html_fc0a77eab94ff78051569f6146506cdf);
#
#
#
#         marker_5f054e3195393eb5865b956f50757656.bindPopup(popup_a53d2d6012714fcab0eb6d7fe906509f)
#         ;
#
#
#
#
#             var marker_39c32ae7ed84af23c6e60dd0aad583f1 = L.marker(
#                 [28.57325457, -80.64689529],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_dfb7df5d91b3801668efc8e44be2ebde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef2420de13eda243bb80611148c2be4 = $(`&lt;div id=&quot;html_eef2420de13eda243bb80611148c2be4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_dfb7df5d91b3801668efc8e44be2ebde.setContent(html_eef2420de13eda243bb80611148c2be4);
#
#
#
#         marker_39c32ae7ed84af23c6e60dd0aad583f1.bindPopup(popup_dfb7df5d91b3801668efc8e44be2ebde)
#         ;
#
#
#
#
#             var marker_eadbba1ebd8489f26463365469735795 = L.marker(
#                 [34.63283416, -120.6107455],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_545df73cb0c7a4b177c8c73e3e4a0b36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c000c35b7868dcabf18e54c843f50b8 = $(`&lt;div id=&quot;html_9c000c35b7868dcabf18e54c843f50b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_545df73cb0c7a4b177c8c73e3e4a0b36.setContent(html_9c000c35b7868dcabf18e54c843f50b8);
#
#
#
#         marker_eadbba1ebd8489f26463365469735795.bindPopup(popup_545df73cb0c7a4b177c8c73e3e4a0b36)
#         ;
#
#
#
#
#             var feature_group_6381005d830a9d02b4c8b93624a9bd68 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_50df35a58ad33c6e57b56f15077d80a1 = L.circleMarker(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_6381005d830a9d02b4c8b93624a9bd68);
#
#
#             var circle_marker_1ef1f0239282528c49809dd60c91dee1 = L.circleMarker(

# %% [markdown]
# We could use `folium.Circle` to add a highlighted circle area with a text label on a specific coordinate. For example,

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d2b9a478fb70972d08824976e5804af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d2b9a478fb70972d08824976e5804af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d2b9a478fb70972d08824976e5804af = L.map(
#                 &quot;map_5d2b9a478fb70972d08824976e5804af&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0317f6701c46ca0dc250269099a72f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0317f6701c46ca0dc250269099a72f3.addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#             var marker_a03b15a6eeb92c066b9803b5333350b9 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_fd0a4d89b7cbbaf71f465620fc75a699 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14adabd1275dbc613706b9df78ca4feb = $(`&lt;div id=&quot;html_14adabd1275dbc613706b9df78ca4feb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_fd0a4d89b7cbbaf71f465620fc75a699.setContent(html_14adabd1275dbc613706b9df78ca4feb);
#
#
#
#         marker_a03b15a6eeb92c066b9803b5333350b9.bindPopup(popup_fd0a4d89b7cbbaf71f465620fc75a699)
#         ;
#
#
#
#
#             var marker_5f054e3195393eb5865b956f50757656 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_a53d2d6012714fcab0eb6d7fe906509f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc0a77eab94ff78051569f6146506cdf = $(`&lt;div id=&quot;html_fc0a77eab94ff78051569f6146506cdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_a53d2d6012714fcab0eb6d7fe906509f.setContent(html_fc0a77eab94ff78051569f6146506cdf);
#
#
#
#         marker_5f054e3195393eb5865b956f50757656.bindPopup(popup_a53d2d6012714fcab0eb6d7fe906509f)
#         ;
#
#
#
#
#             var marker_39c32ae7ed84af23c6e60dd0aad583f1 = L.marker(
#                 [28.57325457, -80.64689529],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_dfb7df5d91b3801668efc8e44be2ebde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef2420de13eda243bb80611148c2be4 = $(`&lt;div id=&quot;html_eef2420de13eda243bb80611148c2be4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_dfb7df5d91b3801668efc8e44be2ebde.setContent(html_eef2420de13eda243bb80611148c2be4);
#
#
#
#         marker_39c32ae7ed84af23c6e60dd0aad583f1.bindPopup(popup_dfb7df5d91b3801668efc8e44be2ebde)
#         ;
#
#
#
#
#             var marker_eadbba1ebd8489f26463365469735795 = L.marker(
#                 [34.63283416, -120.6107455],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_545df73cb0c7a4b177c8c73e3e4a0b36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c000c35b7868dcabf18e54c843f50b8 = $(`&lt;div id=&quot;html_9c000c35b7868dcabf18e54c843f50b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_545df73cb0c7a4b177c8c73e3e4a0b36.setContent(html_9c000c35b7868dcabf18e54c843f50b8);
#
#
#
#         marker_eadbba1ebd8489f26463365469735795.bindPopup(popup_545df73cb0c7a4b177c8c73e3e4a0b36)
#         ;
#
#
#
#
#             var feature_group_6381005d830a9d02b4c8b93624a9bd68 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_50df35a58ad33c6e57b56f15077d80a1 = L.circleMarker(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_6381005d830a9d02b4c8b93624a9bd68);
#
#
#             var circle_marker_1ef1f0239282528c49809dd60c91dee1 = L.circleMarker(

# %% [markdown]
# and you should find a small yellow circle near the city of Houston and you can zoom-in to see a larger circle.

# %% [markdown]
# Now, let's add a circle for each launch site in data frame `launch_sites`

# %% [markdown]
# *TODO:*  Create and add `folium.Circle` and `folium.Marker` for each launch site on the site map

# %% [markdown]
# An example of folium.Circle:

# %% [markdown]
# `folium.Circle(coordinate, radius=1000, color='#000000', fill=True).add_child(folium.Popup(...))`

# %% [markdown]
# An example of folium.Marker:

# %% [markdown]
# `folium.map.Marker(coordinate, icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0), html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'label', ))`

# %%
# Iterar sobre las ubicaciones de los sitios de lanzamiento
for lat, lng, label in zip(launch_sites_df['Lat'], launch_sites_df['Long'], launch_sites_df['Launch Site']):
    # Crear un círculo rojo en cada sitio de lanzamiento
    circle = folium.Circle(
        location=[lat, lng],
        radius=1000,  # Tamaño del círculo en metros
        color='#d35400',  # Color del borde del círculo
        fill=True,
        fill_color='#d35400',  # Color del relleno
        fill_opacity=0.4
    )
    # Crear una etiqueta como marcador
    label_marker = folium.Marker(
        location=[lat, lng],
        icon=folium.DivIcon(
            icon_size=(150, 30),  # Tamaño del ícono
            icon_anchor=(0, 0),  # Anclaje del texto
            html=f'<div style="font-size: 12px; color:#d35400;"><b>{label}</b></div>'  # Etiqueta estilizada
        )
    )
    # Añadir el círculo y la etiqueta al mapa
site_map.add_child(circle)
site_map.add_child(label_marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d2b9a478fb70972d08824976e5804af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d2b9a478fb70972d08824976e5804af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d2b9a478fb70972d08824976e5804af = L.map(
#                 &quot;map_5d2b9a478fb70972d08824976e5804af&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0317f6701c46ca0dc250269099a72f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0317f6701c46ca0dc250269099a72f3.addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#             var marker_a03b15a6eeb92c066b9803b5333350b9 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_fd0a4d89b7cbbaf71f465620fc75a699 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14adabd1275dbc613706b9df78ca4feb = $(`&lt;div id=&quot;html_14adabd1275dbc613706b9df78ca4feb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_fd0a4d89b7cbbaf71f465620fc75a699.setContent(html_14adabd1275dbc613706b9df78ca4feb);
#
#
#
#         marker_a03b15a6eeb92c066b9803b5333350b9.bindPopup(popup_fd0a4d89b7cbbaf71f465620fc75a699)
#         ;
#
#
#
#
#             var marker_5f054e3195393eb5865b956f50757656 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_a53d2d6012714fcab0eb6d7fe906509f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc0a77eab94ff78051569f6146506cdf = $(`&lt;div id=&quot;html_fc0a77eab94ff78051569f6146506cdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_a53d2d6012714fcab0eb6d7fe906509f.setContent(html_fc0a77eab94ff78051569f6146506cdf);
#
#
#
#         marker_5f054e3195393eb5865b956f50757656.bindPopup(popup_a53d2d6012714fcab0eb6d7fe906509f)
#         ;
#
#
#
#
#             var marker_39c32ae7ed84af23c6e60dd0aad583f1 = L.marker(
#                 [28.57325457, -80.64689529],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_dfb7df5d91b3801668efc8e44be2ebde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef2420de13eda243bb80611148c2be4 = $(`&lt;div id=&quot;html_eef2420de13eda243bb80611148c2be4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_dfb7df5d91b3801668efc8e44be2ebde.setContent(html_eef2420de13eda243bb80611148c2be4);
#
#
#
#         marker_39c32ae7ed84af23c6e60dd0aad583f1.bindPopup(popup_dfb7df5d91b3801668efc8e44be2ebde)
#         ;
#
#
#
#
#             var marker_eadbba1ebd8489f26463365469735795 = L.marker(
#                 [34.63283416, -120.6107455],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_545df73cb0c7a4b177c8c73e3e4a0b36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c000c35b7868dcabf18e54c843f50b8 = $(`&lt;div id=&quot;html_9c000c35b7868dcabf18e54c843f50b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_545df73cb0c7a4b177c8c73e3e4a0b36.setContent(html_9c000c35b7868dcabf18e54c843f50b8);
#
#
#
#         marker_eadbba1ebd8489f26463365469735795.bindPopup(popup_545df73cb0c7a4b177c8c73e3e4a0b36)
#         ;
#
#
#
#
#             var feature_group_6381005d830a9d02b4c8b93624a9bd68 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_50df35a58ad33c6e57b56f15077d80a1 = L.circleMarker(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_6381005d830a9d02b4c8b93624a9bd68);
#
#
#             var circle_marker_1ef1f0239282528c49809dd60c91dee1 = L.circleMarker(

# %% [markdown]
# The generated map with marked launch sites should look similar to the following:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_markers.png">
# </center>

# %% [markdown]
# Now, you can explore the map by zoom-in/out the marked areas
# , and try to answer the following questions:
#
# *   Are all launch sites in proximity to the Equator line?
# *   Are all launch sites in very close proximity to the coast?
#
# Also please try to explain your findings.

# %% [markdown]
# # Task 2: Mark the success/failed launches for each site on the map

# %% [markdown]
# Next, let's try to enhance the map by adding the launch outcomes for each site, and see which sites have high success rates.
# Recall that data frame spacex_df has detailed launch records, and the `class` column indicates if this launch was successful or not

# %%
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %% [markdown]
# Next, let's create markers for all launch records.
# If a launch was successful `(class=1)`, then we use a green marker and if a launch was failed, we use a red marker `(class=0)`

# %% [markdown]
# Note that a launch only happens in one of the four launch sites, which means many launch records will have the exact same coordinate. Marker clusters can be a good way to simplify a map containing many markers having the same coordinate.

# %% [markdown]
# Let's first create a `MarkerCluster` object

# %%
marker_cluster = MarkerCluster()

# %% [markdown]
# *TODO:* Create a new column in `spacex_df` dataframe called `marker_color` to store the marker colors based on the `class` value

# %%
from folium.plugins import MarkerCluster

# Create a MarkerCluster object
marker_cluster = MarkerCluster().add_to(site_map)

# Create a new column in launch_sites_df called marker_color
launch_sites_df['marker_color'] = ''

# Function to determine marker color based on the 'class' value
def get_marker_color(row):
    if row['class'] == 1:
        return 'green'  # Successful launch
    else:
        return 'red'    # Failed launch

# Apply the function to create the marker_color column
spacex_df['marker_color'] = spacex_df.apply(get_marker_color, axis=1)

# Loop through each launch record in spacex_df
for index, record in spacex_df.iterrows():
    # Create a Marker for each launch record with the specified color
    marker = folium.Marker(
        [record['Lat'], record['Long']],
        icon=folium.Icon(color=record['marker_color']),
        popup=f"{record['Launch Site']} - {'Success' if record['class'] == 1 else 'Failure'}"
    )

    # Add the Marker to the MarkerCluster
    marker_cluster.add_child(marker)

# Display the map
site_map
# Apply a function to check the value of `class` column
# If class=1, marker_color value will be green
# If class=0, marker_color value will be red
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d2b9a478fb70972d08824976e5804af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d2b9a478fb70972d08824976e5804af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d2b9a478fb70972d08824976e5804af = L.map(
#                 &quot;map_5d2b9a478fb70972d08824976e5804af&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0317f6701c46ca0dc250269099a72f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0317f6701c46ca0dc250269099a72f3.addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#             var marker_a03b15a6eeb92c066b9803b5333350b9 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_fd0a4d89b7cbbaf71f465620fc75a699 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14adabd1275dbc613706b9df78ca4feb = $(`&lt;div id=&quot;html_14adabd1275dbc613706b9df78ca4feb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_fd0a4d89b7cbbaf71f465620fc75a699.setContent(html_14adabd1275dbc613706b9df78ca4feb);
#
#
#
#         marker_a03b15a6eeb92c066b9803b5333350b9.bindPopup(popup_fd0a4d89b7cbbaf71f465620fc75a699)
#         ;
#
#
#
#
#             var marker_5f054e3195393eb5865b956f50757656 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_a53d2d6012714fcab0eb6d7fe906509f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc0a77eab94ff78051569f6146506cdf = $(`&lt;div id=&quot;html_fc0a77eab94ff78051569f6146506cdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_a53d2d6012714fcab0eb6d7fe906509f.setContent(html_fc0a77eab94ff78051569f6146506cdf);
#
#
#
#         marker_5f054e3195393eb5865b956f50757656.bindPopup(popup_a53d2d6012714fcab0eb6d7fe906509f)
#         ;
#
#
#
#
#             var marker_39c32ae7ed84af23c6e60dd0aad583f1 = L.marker(
#                 [28.57325457, -80.64689529],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_dfb7df5d91b3801668efc8e44be2ebde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef2420de13eda243bb80611148c2be4 = $(`&lt;div id=&quot;html_eef2420de13eda243bb80611148c2be4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_dfb7df5d91b3801668efc8e44be2ebde.setContent(html_eef2420de13eda243bb80611148c2be4);
#
#
#
#         marker_39c32ae7ed84af23c6e60dd0aad583f1.bindPopup(popup_dfb7df5d91b3801668efc8e44be2ebde)
#         ;
#
#
#
#
#             var marker_eadbba1ebd8489f26463365469735795 = L.marker(
#                 [34.63283416, -120.6107455],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_545df73cb0c7a4b177c8c73e3e4a0b36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c000c35b7868dcabf18e54c843f50b8 = $(`&lt;div id=&quot;html_9c000c35b7868dcabf18e54c843f50b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_545df73cb0c7a4b177c8c73e3e4a0b36.setContent(html_9c000c35b7868dcabf18e54c843f50b8);
#
#
#
#         marker_eadbba1ebd8489f26463365469735795.bindPopup(popup_545df73cb0c7a4b177c8c73e3e4a0b36)
#         ;
#
#
#
#
#             var feature_group_6381005d830a9d02b4c8b93624a9bd68 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_

# %% [markdown]
# *TODO:* For each launch result in `spacex_df` data frame, add a `folium.Marker` to `marker_cluster`

# %% [markdown]
# Your updated map may look like the following screenshots:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster.png">
# </center>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster_zoomed.png">
# </center>

# %% [markdown]
# From the color-labeled markers in marker clusters, you should be able to easily identify which launch sites have relatively high success rates.

# %% [markdown]
# # TASK 3: Calculate the distances between a launch site to its proximities

# %% [markdown]
# Next, we need to explore and analyze the proximities of launch sites.

# %% [markdown]
# Let's first add a `MousePosition` on the map to get coordinate for a mouse over a point on the map. As such, while you are exploring the map, you can easily find the coordinates of any points of interests (such as railway)

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d2b9a478fb70972d08824976e5804af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d2b9a478fb70972d08824976e5804af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d2b9a478fb70972d08824976e5804af = L.map(
#                 &quot;map_5d2b9a478fb70972d08824976e5804af&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0317f6701c46ca0dc250269099a72f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0317f6701c46ca0dc250269099a72f3.addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#             var marker_a03b15a6eeb92c066b9803b5333350b9 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_fd0a4d89b7cbbaf71f465620fc75a699 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14adabd1275dbc613706b9df78ca4feb = $(`&lt;div id=&quot;html_14adabd1275dbc613706b9df78ca4feb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_fd0a4d89b7cbbaf71f465620fc75a699.setContent(html_14adabd1275dbc613706b9df78ca4feb);
#
#
#
#         marker_a03b15a6eeb92c066b9803b5333350b9.bindPopup(popup_fd0a4d89b7cbbaf71f465620fc75a699)
#         ;
#
#
#
#
#             var marker_5f054e3195393eb5865b956f50757656 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_a53d2d6012714fcab0eb6d7fe906509f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc0a77eab94ff78051569f6146506cdf = $(`&lt;div id=&quot;html_fc0a77eab94ff78051569f6146506cdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_a53d2d6012714fcab0eb6d7fe906509f.setContent(html_fc0a77eab94ff78051569f6146506cdf);
#
#
#
#         marker_5f054e3195393eb5865b956f50757656.bindPopup(popup_a53d2d6012714fcab0eb6d7fe906509f)
#         ;
#
#
#
#
#             var marker_39c32ae7ed84af23c6e60dd0aad583f1 = L.marker(
#                 [28.57325457, -80.64689529],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_dfb7df5d91b3801668efc8e44be2ebde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef2420de13eda243bb80611148c2be4 = $(`&lt;div id=&quot;html_eef2420de13eda243bb80611148c2be4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_dfb7df5d91b3801668efc8e44be2ebde.setContent(html_eef2420de13eda243bb80611148c2be4);
#
#
#
#         marker_39c32ae7ed84af23c6e60dd0aad583f1.bindPopup(popup_dfb7df5d91b3801668efc8e44be2ebde)
#         ;
#
#
#
#
#             var marker_eadbba1ebd8489f26463365469735795 = L.marker(
#                 [34.63283416, -120.6107455],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_545df73cb0c7a4b177c8c73e3e4a0b36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c000c35b7868dcabf18e54c843f50b8 = $(`&lt;div id=&quot;html_9c000c35b7868dcabf18e54c843f50b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_545df73cb0c7a4b177c8c73e3e4a0b36.setContent(html_9c000c35b7868dcabf18e54c843f50b8);
#
#
#
#         marker_eadbba1ebd8489f26463365469735795.bindPopup(popup_545df73cb0c7a4b177c8c73e3e4a0b36)
#         ;
#
#
#
#
#             var feature_group_6381005d830a9d02b4c8b93624a9bd68 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# *TODO:* Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch site.

# %%
# find coordinate of the closet coastline
# e.g.,: Lat: 28.56367  Lon: -80.57163
# Assume these are the coordinates of the closest coastline obtained from MousePosition
coastline_lat = 28.56367
coastline_lon = -80.568

# Coordinates of the launch site
launch_site_lat = 28.5634
launch_site_lon = -80.57677

# Calculate the distance between the launch site and the coastline
distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

print(f"Distance to the closest coastline: {distance_coastline:.2f} km")
# Out:
# Distance to the closest coastline: 0.86 km

# %% [markdown]
# *TODO:* Draw a `PolyLine` between a launch site to the selected coastline point

# %%
coastline_lat = 28.56367
coastline_lon = -80.568

# Calculate the distance between the launch site and the coastline
distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

# Create a Marker for the closest coastline point
coastline_marker = folium.Marker(
    [coastline_lat, coastline_lon],
    icon=DivIcon(
        icon_size=(20, 20),
        icon_anchor=(0, 0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline),
    ),
    popup='Closest Coastline Point'
)

# Add the Marker to the map
site_map.add_child(coastline_marker)

lines = folium.PolyLine(locations=[[launch_site_lat, launch_site_lon], [coastline_lat, coastline_lon]], weight=1)

# Add the PolyLine to the map
site_map.add_child(lines)

# Display the map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d2b9a478fb70972d08824976e5804af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d2b9a478fb70972d08824976e5804af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d2b9a478fb70972d08824976e5804af = L.map(
#                 &quot;map_5d2b9a478fb70972d08824976e5804af&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0317f6701c46ca0dc250269099a72f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0317f6701c46ca0dc250269099a72f3.addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#             var marker_a03b15a6eeb92c066b9803b5333350b9 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_fd0a4d89b7cbbaf71f465620fc75a699 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14adabd1275dbc613706b9df78ca4feb = $(`&lt;div id=&quot;html_14adabd1275dbc613706b9df78ca4feb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_fd0a4d89b7cbbaf71f465620fc75a699.setContent(html_14adabd1275dbc613706b9df78ca4feb);
#
#
#
#         marker_a03b15a6eeb92c066b9803b5333350b9.bindPopup(popup_fd0a4d89b7cbbaf71f465620fc75a699)
#         ;
#
#
#
#
#             var marker_5f054e3195393eb5865b956f50757656 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_a53d2d6012714fcab0eb6d7fe906509f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc0a77eab94ff78051569f6146506cdf = $(`&lt;div id=&quot;html_fc0a77eab94ff78051569f6146506cdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_a53d2d6012714fcab0eb6d7fe906509f.setContent(html_fc0a77eab94ff78051569f6146506cdf);
#
#
#
#         marker_5f054e3195393eb5865b956f50757656.bindPopup(popup_a53d2d6012714fcab0eb6d7fe906509f)
#         ;
#
#
#
#
#             var marker_39c32ae7ed84af23c6e60dd0aad583f1 = L.marker(
#                 [28.57325457, -80.64689529],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_dfb7df5d91b3801668efc8e44be2ebde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef2420de13eda243bb80611148c2be4 = $(`&lt;div id=&quot;html_eef2420de13eda243bb80611148c2be4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_dfb7df5d91b3801668efc8e44be2ebde.setContent(html_eef2420de13eda243bb80611148c2be4);
#
#
#
#         marker_39c32ae7ed84af23c6e60dd0aad583f1.bindPopup(popup_dfb7df5d91b3801668efc8e44be2ebde)
#         ;
#
#
#
#
#             var marker_eadbba1ebd8489f26463365469735795 = L.marker(
#                 [34.63283416, -120.6107455],
#                 {
# }
#             ).addTo(map_5d2b9a478fb70972d08824976e5804af);
#
#
#         var popup_545df73cb0c7a4b177c8c73e3e4a0b36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c000c35b7868dcabf18e54c843f50b8 = $(`&lt;div id=&quot;html_9c000c35b7868dcabf18e54c843f50b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_545df73cb0c7a4b177c8c73e3e4a0b36.setContent(html_9c000c35b7868dcabf18e54c843f50b8);
#
#
#
#         marker_eadbba1ebd8489f26463365469735795.bindPopup(popup_545df73cb0c7a4b177c8c73e3e4a0b36)
#         ;
#
#
#
#
#             var feature_group_6381005d830a9d02b4c8b93624a9bd68 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_

# %% [markdown]
# Your updated map with distance line should look like the following screenshot:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_distance.png">
# </center>

# %% [markdown]
# *TODO:* Similarly, you can draw a line betwee a launch site to its closest city, railway, highway, etc. You need to use `MousePosition` to find the their coordinates on the map first

# %% [markdown]
# A railway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/railway.png">
# </center>

# %% [markdown]
# A highway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/highway.png">
# </center>

# %% [markdown]
# A city map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/city.png">
# </center>

# %%
# Create a marker with distance to a closest city, railway, highway, etc.
# Draw a line between the marker to the launch site

# %%
import folium
from folium import DivIcon
from math import sin, cos, sqrt, atan2, radians

# Coordenadas del sitio de lanzamiento
launch_site_lat = 28.5634
launch_site_lon = -80.57677

# Coordenadas de los sitios de interés
highway_lat = 28.41162
highway_lon = -80.82026

railway_lat = 28.54851
railway_lon = -81.38086

city_lat = 28.61346
city_lon = -80.8077

# Calcular distancias
distance_highway = calculate_distance(launch_site_lat, launch_site_lon, highway_lat, highway_lon)
distance_railway = calculate_distance(launch_site_lat, launch_site_lon, railway_lat, railway_lon)
distance_city = calculate_distance(launch_site_lat, launch_site_lon, city_lat, city_lon)

# Crear un mapa centrado en el sitio de lanzamiento
site_map = folium.Map(location=[launch_site_lat, launch_site_lon], zoom_start=10)

# Agregar marcador para el sitio de lanzamiento
launch_marker = folium.Marker(
    [launch_site_lat, launch_site_lon],
    popup="CCAFS-SLC-40",
    icon=folium.Icon(color='blue', icon='rocket')
)
site_map.add_child(launch_marker)

# Agregar marcador para la autopista
highway_marker = folium.Marker(
    [highway_lat, highway_lon],
    icon=DivIcon(
        icon_size=(20, 20),
        icon_anchor=(0, 0),
        html='<div style="font-size: 12px; color:#d35400;"><b>{:.2f} KM</b></div>'.format(distance_highway),
    ),
    popup='Closest Highway'
)
site_map.add_child(highway_marker)

# Línea entre el sitio de lanzamiento y la autopista
folium.PolyLine(
    locations=[
        [launch_site_lat, launch_site_lon],
        [highway_lat, highway_lon]
    ],
    color='green',
    weight=2.5,
    opacity=0.8
).add_to(site_map)

# Agregar marcador para la estación de tren
railway_marker = folium.Marker(
    [railway_lat, railway_lon],
    icon=DivIcon(
        icon_size=(20, 20),
        icon_anchor=(0, 0),
        html='<div style="font-size: 12px; color:#d35400;"><b>{:.2f} KM</b></div>'.format(distance_railway),
    ),
    popup='Railway Station'
)
site_map.add_child(railway_marker)

# Línea entre el sitio de lanzamiento y la estación de tren
folium.PolyLine(
    locations=[
        [launch_site_lat, launch_site_lon],
        [railway_lat, railway_lon]
    ],
    color='purple',
    weight=2.5,
    opacity=0.8
).add_to(site_map)

# Agregar marcador para la ciudad
city_marker = folium.Marker(
    [city_lat, city_lon],
    icon=DivIcon(
        icon_size=(20, 20),
        icon_anchor=(0, 0),
        html='<div style="font-size: 12px; color:#d35400;"><b>{:.2f} KM</b></div>'.format(distance_city),
    ),
    popup='Closest City'
)
site_map.add_child(city_marker)

# Línea entre el sitio de lanzamiento y la ciudad
folium.PolyLine(
    locations=[
        [launch_site_lat, launch_site_lon],
        [city_lat, city_lon]
    ],
    color='red',
    weight=2.5,
    opacity=0.8
).add_to(site_map)

# Mostrar el mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec3f525feed33b16a02bb3c8dc3a5c47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec3f525feed33b16a02bb3c8dc3a5c47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec3f525feed33b16a02bb3c8dc3a5c47 = L.map(
#                 &quot;map_ec3f525feed33b16a02bb3c8dc3a5c47&quot;,
#                 {
#                     center: [28.5634, -80.57677],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_588c9b4866ef3c0a2e7bab567b34abf8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_588c9b4866ef3c0a2e7bab567b34abf8.addTo(map_ec3f525feed33b16a02bb3c8dc3a5c47);
#
#
#             var marker_e3365ced4bc0eb2e062cb0318cf31631 = L.marker(
#                 [28.5634, -80.57677],
#                 {
# }
#             ).addTo(map_ec3f525feed33b16a02bb3c8dc3a5c47);
#
#
#             var icon_f60a631abc9e8069e8244d33e4ba9d95 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_e3365ced4bc0eb2e062cb0318cf31631.setIcon(icon_f60a631abc9e8069e8244d33e4ba9d95);
#
#
#         var popup_4bc2fbc918291af321d109008fc0cc5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3a20d4b90973829c29bc69d816106ab = $(`&lt;div id=&quot;html_c3a20d4b90973829c29bc69d816106ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS-SLC-40&lt;/div&gt;`)[0];
#                 popup_4bc2fbc918291af321d109008fc0cc5c.setContent(html_c3a20d4b90973829c29bc69d816106ab);
#
#
#
#         marker_e3365ced4bc0eb2e062cb0318cf31631.bindPopup(popup_4bc2fbc918291af321d109008fc0cc5c)
#         ;
#
#
#
#
#             var marker_f28ed3a20126787c805d481297929d77 = L.marker(
#                 [28.41162, -80.82026],
#                 {
# }
#             ).addTo(map_ec3f525feed33b16a02bb3c8dc3a5c47);
#
#
#             var div_icon_e7fc4d1a13fde6dd2449e4eb87e610df = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:#d35400;\&quot;\u003e\u003cb\u003e29.18 KM\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_f28ed3a20126787c805d481297929d77.setIcon(div_icon_e7fc4d1a13fde6dd2449e4eb87e610df);
#
#
#         var popup_07a425fc4ac0d5d74784275c9c333e5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d6a2929d179fb0b7395ece1fcfbd8e0 = $(`&lt;div id=&quot;html_3d6a2929d179fb0b7395ece1fcfbd8e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Closest Highway&lt;/div&gt;`)[0];
#                 popup_07a425fc4ac0d5d74784275c9c333e5b.setContent(html_3d6a2929d179fb0b7395ece1fcfbd8e0);
#
#
#
#         marker_f28ed3a20126787c805d481297929d77.bindPopup(popup_07a425fc4ac0d5d74784275c9c333e5b)
#         ;
#
#
#
#
#             var poly_line_f55172e0faaa730ce68e58b43c24d4a1 = L.polyline(
#                 [[28.5634, -80.57677], [28.41162, -80.82026]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_ec3f525feed33b16a02bb3c8dc3a5c47);
#
#
#             var marker_ab6c51fb938a0e1310536226db95d90b = L.marker(
#                 [28.54851, -81.38086],
#                 {
# }
#             ).addTo(map_ec3f525feed33b16a02bb3c8dc3a5c47);
#
#
#             var div_icon_f4c4f1327327332ac68abddb5cc9e9b3 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:#d35400;\&quot;\u003e\u003cb\u003e78.58 KM\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_ab6c51fb938a0e1310536226db95d90b.setIcon(div_icon_f4c4f1327327332ac68abddb5cc9e9b3);
#
#
#         var popup_e86a16d7cd1bc8ce7196b0e069dccd33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35b8f4c6a610db7eca84fc943904d804 = $(`&lt;div id=&quot;html_35b8f4c6a610db7

# %% [markdown]
# After you plot distance lines to the proximities, you can answer the following questions easily:
#
# *   Are launch sites in close proximity to railways?
# *   Are launch sites in close proximity to highways?
# *   Are launch sites in close proximity to coastline?
# *   Do launch sites keep certain distance away from cities?
#
# Also please try to explain your findings.

# %% [markdown]
# # Next Steps:
#
# Now you have discovered many interesting insights related to the launch sites' location using folium, in a very interactive way. Next, you will need to build a dashboard using Ploty Dash on detailed launch records.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Pratiksha Verma](https://www.linkedin.com/in/pratiksha-verma-6487561b1/)

# %% [markdown]
# <!--## Change Log--!>

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By      | Change Description      |
# | ----------------- | ------- | -------------   | ----------------------- |
# | 2022-11-09        | 1.0     | Pratiksha Verma | Converted initial version to Jupyterlite|--!>

# %% [markdown]
# ### <h3 align="center"> IBM Corporation 2022. All rights reserved. <h3/>
